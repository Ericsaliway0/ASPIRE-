# %% [markdown]
# # 02 — Driver vs. Non-Driver Gene Labeling Pipeline
#
# Builds the final driver/non-driver gene label set:
#
# 1. Protein-coding gene universe (GENCODE, `gene_type == "protein_coding"` only)
# 2. Driver genes (COSMIC CGC) as positives
# 3. Negative candidates excluded from **NCG + CGC + IntOGen + Bailey et al. 2018** — not just CGC
# 4. Mutation-frequency filter (excludes genes frequently mutated in any TCGA cancer type)
# 5. Disease-pathway filter (Reactome, restricted to descendants of the top-level *Disease* pathway)
# 6. **Length- and expression- (optionally mutation-rate-) matched negative sampling**, so negatives
#    aren't just "whatever survived the filters" but are matched to the positives' covariate
#    distribution
#
# This notebook is a runnable, cell-by-cell version of `scripts/run_driver_labeling_pipeline.py` —
# it imports the same `src/` modules, so there's no logic duplicated between the notebook and the
# package.
#
# **Requires** (see `config.py` and the README for expected paths):
# - GENCODE GTF annotation
# - COSMIC Cancer Gene Census TSV
# - `data/mutation_frequency_tcga.csv` (produced by notebook 01)
# - Reactome `ReactomePathways.gmt` + pathway relations CSV
# - NCG / IntOGen / Bailey driver lists (optional — skipped if absent)
# - Gene median expression CSV (required only if matched negative sampling is enabled)

# %%
import sys
import os
import random
from pathlib import Path

# Notebooks live in notebooks/, but config.py's paths (e.g. "data/...") are
# relative to the repo root — chdir there so those paths resolve correctly
# regardless of where Jupyter's working directory starts out.
if Path.cwd().name == "notebooks":
    os.chdir(Path.cwd().parent)
sys.path.insert(0, str(Path.cwd()))

import pandas as pd

import config
from src.gene_universe import build_protein_coding_gene_universe
from src.pathway_filter import build_disease_pathway_genes
from src.driver_labeling import (
    apply_mutation_frequency_filter,
    apply_pathway_filter,
    build_gene_labels,
    load_driver_genes,
)
from src.negative_sampling import (
    build_driver_exclusion_set,
    compute_gene_lengths,
    load_gene_expression,
    load_gene_mutation_rate,
    match_negatives,
    summarize_matching_quality,
    build_covariate_table,
)

# %%
random.seed(config.RANDOM_SEED)

config.DATA_DIR.mkdir(parents=True, exist_ok=True)
config.PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print(f"USE_MUTATION_FILTER: {config.USE_MUTATION_FILTER}")
print(f"USE_PATHWAY_FILTER: {config.USE_PATHWAY_FILTER}")
print(f"USE_MATCHED_NEGATIVE_SAMPLING: {config.USE_MATCHED_NEGATIVE_SAMPLING}")
print(f"NEGATIVES_PER_POSITIVE: {config.NEGATIVES_PER_POSITIVE}")
print(f"MATCH_ON_MUTATION_RATE: {config.MATCH_ON_MUTATION_RATE}")
# Out:
# USE_MUTATION_FILTER: True
# USE_PATHWAY_FILTER: True
# USE_MATCHED_NEGATIVE_SAMPLING: True
# NEGATIVES_PER_POSITIVE: 1
# MATCH_ON_MUTATION_RATE: False

# %% [markdown]
# ## 1. Protein-coding gene universe
#
# Parses the GENCODE GTF and keeps only `gene_type == "protein_coding"` entries — excluding
# lncRNAs, pseudogenes, miRNAs, and other non-coding biotypes that would otherwise inflate the
# gene universe (~77,000 -> ~20,000 genes).

# %%
all_genes = build_protein_coding_gene_universe("../../data/gencode.v49.basic.annotation.gtf")

pd.DataFrame(sorted(all_genes), columns=["gene_name"]).to_csv(
    config.GENCODE_GENES_FILE, index=False
)

print(f"[GENE UNIVERSE] {len(all_genes)} protein-coding genes")
# Out:
# [GENE UNIVERSE] 20070 protein-coding genes

# %% [markdown]
# ## 2. Driver genes and the expanded exclusion set
#
# Positives are defined by the COSMIC Cancer Gene Census, as before. But a gene is only eligible
# to be sampled as a **negative** if it is absent from *all four* driver references (NCG, CGC,
# IntOGen, Bailey et al. 2018) — a gene with driver evidence anywhere shouldn't be usable as a
# "confirmed non-driver," even if it isn't in CGC specifically.

# %%
driver_genes = load_driver_genes("../../data/Census_allWed.tsv")
print(f"[DRIVERS] {len(driver_genes)} driver genes (CGC)")

driver_exclusion_set = build_driver_exclusion_set(
    ncg_file=config.NCG_FILE if config.NCG_FILE.exists() else None,
    cgc_file=config.CGC_CENSUS_FILE if config.CGC_CENSUS_FILE.exists() else None,
    intogen_file=config.INTOGEN_FILE if config.INTOGEN_FILE.exists() else None,
    bailey_file=config.BAILEY_FILE if config.BAILEY_FILE.exists() else None,
)

non_drivers = all_genes - driver_exclusion_set
print(f"[NON-DRIVERS] {len(non_drivers)} raw non-driver candidates "
      "(excluded from NCG/CGC/IntOGen/Bailey)")
# Out:
# [DRIVERS] 763 driver genes (CGC)
# [NCG] skipped (no file provided)
# [CGC] 763 genes
# [IntOGen] skipped (no file provided)
# [Bailey et al.] skipped (no file provided)
# [DRIVER EXCLUSION SET] 763 unique genes across all sources
# [NON-DRIVERS] 19326 raw non-driver candidates (excluded from NCG/CGC/IntOGen/Bailey)

# %% [markdown]
# ## 3. Mutation-frequency filter
#
# Excludes any candidate with mutation frequency >= `config.MUTATION_FREQUENCY_THRESHOLD` in any
# TCGA cancer type. Genes never observed mutated at all are correctly treated as 0% frequency
# (kept), not dropped by omission.

# %%
if config.USE_MUTATION_FILTER:
    before = len(non_drivers)
    non_drivers = apply_mutation_frequency_filter(
        non_drivers,
        config.MUTATION_FREQUENCY_FILE,
        threshold=config.MUTATION_FREQUENCY_THRESHOLD,
    )
    print(f"[MUTATION FILTER] {len(non_drivers)} remaining (-{before - len(non_drivers)})")
# Out:
# [MUTATION FILTER] 2491 remaining (-16835)

# %% [markdown]
# ## 4. Disease-pathway filter
#
# Excludes candidates belonging to a Reactome pathway that is a descendant of the top-level
# *Disease* pathway (`R-HSA-1643685`), restricting the exclusion to disease-relevant biology
# rather than the entire Reactome catalog.

# %%
if config.USE_PATHWAY_FILTER:
    pathway_genes = build_disease_pathway_genes(
        "../../data/reactome/ReactomePathways.gmt", "../../data/reactome/reactome_relations.csv"
    )
    pd.DataFrame(sorted(pathway_genes), columns=["gene"]).to_csv(
        config.DISEASE_PATHWAY_GENES_FILE, index=False
    )
    print(f"[PATHWAY FILTER] {len(pathway_genes)} disease-pathway genes")

    before = len(non_drivers)
    non_drivers = apply_pathway_filter(non_drivers, pathway_genes)
    print(f"[PATHWAY FILTER] {len(non_drivers)} remaining (-{before - len(non_drivers)})")
# Out:
# [PATHWAY FILTER] kept 782 disease-related pathways, skipped 2048 unrelated pathways
# [PATHWAY FILTER] 2505 disease-pathway genes
# [PATHWAY FILTER] 2421 remaining (-70)

# %% [markdown]
# ## 5. Length- and expression-matched negative sampling
#
# Rather than keeping every surviving candidate as a negative, each driver gene is matched to its
# nearest unused candidate(s) in log-transformed, z-scored covariate space (gene length,
# expression, and optionally mutation rate). This corrects for drivers tending to be longer and
# more highly expressed than a random background gene.

# %%
if config.USE_MATCHED_NEGATIVE_SAMPLING:
    gene_lengths = compute_gene_lengths("../../data/gencode.v49.basic.annotation.gtf")
    gene_expression = load_gene_expression("../../data/gene_median_expression.csv")
    mutation_rate = (
        load_gene_mutation_rate(config.MUTATION_FREQUENCY_FILE)
        if config.MATCH_ON_MUTATION_RATE
        else None
    )

    match_df = match_negatives(
        positive_genes=driver_genes,
        candidate_negative_genes=non_drivers,
        gene_lengths=gene_lengths,
        gene_expression=gene_expression,
        mutation_rate=mutation_rate,
        n_per_positive=config.NEGATIVES_PER_POSITIVE,
        random_seed=config.RANDOM_SEED,
    )

    matched_negatives = set(match_df["matched_negative_gene"])
    print(
        f"[MATCHED NEGATIVES] {len(matched_negatives)} negatives matched to "
        f"{len(driver_genes)} positives"
    )

    match_df.to_csv(config.PROCESSED_DIR / "negative_gene_matches.csv", index=False)
    match_df.head()
# Out:
# [COVARIATES] dropped 16/763 genes missing a covariate value
# [COVARIATES] dropped 947/2421 genes missing a covariate value
# [MATCHING] warning: only found 0/1 unused matches for 'GAS7' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RAD50' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RAP1GDS1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NOTCH2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NSD3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EXT2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ITGAV' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NFIB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FBLN2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZBTB16' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TCF12' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SOS1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LHFPL6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PTPN11' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ETV6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DNM2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SHTN1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KAT6A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CREB3L2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAX' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'WWTR1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TRIM33' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CTNNB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EGFR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PIK3CB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ACVR1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TRRAP' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NDRG1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PIK3R1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PCM1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARID1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARHGEF10' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NF2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PICALM' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MSN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'STAT3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MGMT' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZNRF3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PPP2R1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NCOR2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAP2K1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DEK' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SUZ12' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'XPO1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARHGAP35' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TSC2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NSD2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AFF1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AFF4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CRTC3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CCDC6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CREBBP' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CDK12' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NUP98' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NCOA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TOP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ABL1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CTNND1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CBFA2T3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'HIF1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MTOR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARHGEF10L' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TBL1XR1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MLH1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FGFR2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KDM5C' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RALGDS' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NFE2L2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MITF' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CBLB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FOXO3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAP2K4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PML' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARNT' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DGCR8' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PTPRK' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SMARCB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SND1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ERC1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CREB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ELL' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SMAD3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'STAG2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ACVR1B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TFRC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MET' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RICTOR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EED' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NF1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TCEA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LMO2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CRTC1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PLCG1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AKT1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CDH1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PTEN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ABI1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LATS2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'POT1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ERBB2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FUBP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MALT1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PRKAR1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NOTCH1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BCR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SMARCA4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KDSR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LEPROTL1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CDK6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FKBP9' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SUB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FAT1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PDGFRA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SDHD' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CHD2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SMC1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RASA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'JAZF1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ITGB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'UBR5' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LMNA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CUX1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZFHX3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZNF331' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LARP4B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KMT2A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CAMTA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MSI2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FIP1L1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SNX29' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TPM3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KIT' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CCND2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FGFR1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'YAP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ATM' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DCTN1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CHIC2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'GOPC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PRKACA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'USP9X' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'WNK2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BCOR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LYN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SETD1B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SRC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DNAJB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FLCN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PABPC1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PBX1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'QKI' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MSH2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PTPRD' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SPECC1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PAFAH1B2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'IGF2BP2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARID1B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DDR2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AKT3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SKI' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CBFB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'IKBKB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MECOM' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LSM14A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DNMT3A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FBXW7' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EBF1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ELF4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SETD2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SETDB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MDM4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'GPC3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BMPR1A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MLLT10' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PLEC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'APC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MLLT6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'STRN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FH' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FANCC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RNF213' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SGK1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAPK1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ATR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SUFU' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TAF15' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ACVR2A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'IDH1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TRIP11' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TCF3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'GRIN2A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NUMA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NCOA2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SYK' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ASPSCR1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PDGFRB' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SDC4' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SETBP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MRTFA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CSF1R' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CPEB3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BIRC6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'GTF2I' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ROCK1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ROBO2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CLIP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARHGAP26' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KAT6B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TPR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SPEN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FLI1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZNF521' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LCP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AKAP9' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'SPOP' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'GMPS' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'YWHAE' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DICER1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DROSHA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AFDN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CSMD3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'POLG' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZMYM2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MB21D2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KIF5B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TFG' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MED12' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'AKT2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CLTCL1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RRAS2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KRAS' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CDKN1B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DDX3X' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'STAT5B' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'KDM5A' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ARHGEF12' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CTNNA1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'HOOK3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'POLE' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TGFBR2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EXT1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BCORL1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAP2K2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EZR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CASP8' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FOXP1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MYH9' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'MAP3K1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ERG' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PRRX1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BCL6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FOXO1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ALDH2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'TCF7L2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'LIFR' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'PRCC' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CNBD1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NTRK2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CHST11' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'STAG1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'DDX6' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RHOA' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ZEB1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'JAK1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RAF1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'EPAS1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RSPO3' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'USP8' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'BCL2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'CEP89' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'FHIT' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'NT5C2' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ELN' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'RPN1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ASXL1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] warning: only found 0/1 unused matches for 'ETNK1' — negative candidate pool may be too small or too dissimilar in this region of covariate space
# [MATCHING] matched 470/747 positive genes to 470 unique negative genes
# [MATCHED NEGATIVES] 470 negatives matched to 763 positives

# %% [markdown]
# ### Check matching quality
#
# Compares median length/expression(/mutation rate) across positives, the matched negatives, and the full unmatched candidate pool. Matched negatives should sit close to positives; the unmatched pool should not — that gap is the evidence the matching worked.

# %%
if config.USE_MATCHED_NEGATIVE_SAMPLING:
    pos_covariates = build_covariate_table(
        driver_genes, gene_lengths, gene_expression, mutation_rate
    )
    quality_report = summarize_matching_quality(
        pos_df=pos_covariates,
        matched_negative_genes=matched_negatives,
        unmatched_candidate_genes=non_drivers,
        gene_lengths=gene_lengths,
        gene_expression=gene_expression,
        mutation_rate=mutation_rate,
    )
    quality_report.to_csv(config.PROCESSED_DIR / "negative_matching_quality.csv", index=False)

    non_drivers = matched_negatives
    quality_report
# Out:
# [COVARIATES] dropped 16/763 genes missing a covariate value
# [COVARIATES] dropped 947/2421 genes missing a covariate value

# %% [markdown]
# ## 6. Build and save the final labeled gene table

# %%
labels_df = build_gene_labels(driver_genes, non_drivers)
print(labels_df["label"].value_counts())

labels_df.to_csv(config.GENE_LABELS_FILE, index=False)
print(f"[DONE] Saved -> {config.GENE_LABELS_FILE}")

driver_path = config.PROCESSED_DIR / "driver_genes.txt"
with open(driver_path, "w") as f:
    for gene in driver_genes:
        f.write(f"{gene}\n")

nondriver_path = config.PROCESSED_DIR / "non_driver_genes.txt"
with open(nondriver_path, "w") as f:
    for gene in non_drivers:
        f.write(f"{gene}\n")

print(f"[DONE] Saved driver genes -> {driver_path}")
print(f"[DONE] Saved non-driver genes -> {nondriver_path}")
labels_df.head()
# Out:
# label
# 1    763
# 0    470
# Name: count, dtype: int64
# [DONE] Saved -> ../data/processed/gene_labels_driver_vs_nondriver.csv
# [DONE] Saved driver genes -> ../data/processed/driver_genes.txt
# [DONE] Saved non-driver genes -> ../data/processed/non_driver_genes.txt
#       gene  label
# 0    PRKCB      1
# 1   MAP2K2      1
# 2   SH3GL1      1
# 3  SMARCA4      1
# 4    FANCC      1
